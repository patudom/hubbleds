# %%
from warnings import filterwarnings

filterwarnings(action="ignore", category=UserWarning)

from cosmicds.app import Application


# app = Application(story='hubbles_law', update_db=True, show_team_interface=True, allow_advancing=True, create_new_student=True)
app = Application(story='hubbles_law', update_db=True, show_team_interface=True, allow_advancing=True, student_id=4071) #4071 is in beta class 187; 4073 not in a class

app
# Out:
# Application(app_state=<ApplicationState
#   allow_advancing: True
#   classroom: {'id': 187, 'name': 'Beta 2 Test …
# WARNING:Comm:No such comm: b139dcc784c54705a97cbad80638763b
# WARNING:Comm:No such comm: b139dcc784c54705a97cbad80638763b
# WARNING:Comm:No such comm: b139dcc784c54705a97cbad80638763b
# WARNING:Comm:No such comm: b139dcc784c54705a97cbad80638763b
# WARNING:Comm:No such comm: b139dcc784c54705a97cbad80638763b
# WARNING:Comm:No such comm: b139dcc784c54705a97cbad80638763b
# Exception in thread Thread-460:
# Traceback (most recent call last):
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/site-packages/requests/models.py", line 511, in prepare_body
#     body = complexjson.dumps(json, allow_nan=False)
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/json/__init__.py", line 234, in dumps
#     return cls(
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
# ValueError: Out of range float values are not JSON compliant
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/threading.py", line 1254, in run
#     self.function(*self.args, **self.kwargs)
#   File "/Users/Pat/Documents/GitHub/cosmicds/cosmicds/utils.py", line 295, in call_it
#     fun(*args, **kwargs)
#   File "/Users/Pat/Documents/GitHub/cosmicds/cosmicds/phases.py", line 68, in write_to_db
#     self.hub.broadcast(WriteToDatabaseMessage(self))
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/site-packages/glue/core/hub.py", line 215, in broadcast
#     handler(message)
#   File "/Users/Pat/Documents/GitHub/cosmicds/cosmicds/app.py", line 194, in _on_write_to_database
#     requests.put(self.story_state_endpoint, json=data)
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/site-packages/requests/api.py", line 130, in put
#     return request("put", url, data=data, **kwargs)
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/site-packages/requests/api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/site-packages/requests/sessions.py", line 573, in request
#     prep = self.prepare_request(req)
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/site-packages/requests/sessions.py", line 484, in prepare_request
#     p.prepare(
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/site-packages/requests/models.py", line 371, in prepare
#     self.prepare_body(data, files, json)
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/site-packages/requests/models.py", line 513, in prepare_body
#     raise InvalidJSONError(ve, request=self)
# requests.exceptions.InvalidJSONError: Out of range float values are not JSON compliant
# Exception in thread Thread-879:
# Traceback (most recent call last):
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/site-packages/requests/models.py", line 511, in prepare_body
#     body = complexjson.dumps(json, allow_nan=False)
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/json/__init__.py", line 234, in dumps
#     return cls(
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
# ValueError: Out of range float values are not JSON compliant
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/threading.py", line 1254, in run
#     self.function(*self.args, **self.kwargs)
#   File "/Users/Pat/Documents/GitHub/cosmicds/cosmicds/utils.py", line 295, in call_it
#     fun(*args, **kwargs)
#   File "/Users/Pat/Documents/GitHub/cosmicds/cosmicds/phases.py", line 68, in write_to_db
#     self.hub.broadcast(WriteToDatabaseMessage(self))
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/site-packages/glue/core/hub.py", line 215, in broadcast
#     handler(message)
#   File "/Users/Pat/Documents/GitHub/cosmicds/cosmicds/app.py", line 194, in _on_write_to_database
#     requests.put(self.story_state_endpoint, json=data)
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/site-packages/requests/api.py", line 130, in put
#     return request("put", url, data=data, **kwargs)
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/site-packages/requests/api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/site-packages/requests/sessions.py", line 573, in request
#     prep = self.prepare_request(req)
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/site-packages/requests/sessions.py", line 484, in prepare_request
#     p.prepare(
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/site-packages/requests/models.py", line 371, in prepare
#     self.prepare_body(data, files, json)
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/site-packages/requests/models.py", line 513, in prepare_body
#     raise InvalidJSONError(ve, request=self)
# requests.exceptions.InvalidJSONError: Out of range float values are not JSON compliant
# Exception in thread Thread-2727:
# Traceback (most recent call last):
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/site-packages/requests/models.py", line 511, in prepare_body
#     body = complexjson.dumps(json, allow_nan=False)
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/json/__init__.py", line 234, in dumps
#     return cls(
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
# ValueError: Out of range float values are not JSON compliant
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/threading.py", line 1254, in run
#     self.function(*self.args, **self.kwargs)
#   File "/Users/Pat/Documents/GitHub/cosmicds/cosmicds/utils.py", line 295, in call_it
#     fun(*args, **kwargs)
#   File "/Users/Pat/Documents/GitHub/cosmicds/cosmicds/phases.py", line 68, in write_to_db
#     self.hub.broadcast(WriteToDatabaseMessage(self))
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/site-packages/glue/core/hub.py", line 215, in broadcast
#     handler(message)
#   File "/Users/Pat/Documents/GitHub/cosmicds/cosmicds/app.py", line 194, in _on_write_to_database
#     requests.put(self.story_state_endpoint, json=data)
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/site-packages/requests/api.py", line 130, in put
#     return request("put", url, data=data, **kwargs)
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/site-packages/requests/api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/site-packages/requests/sessions.py", line 573, in request
#     prep = self.prepare_request(req)
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/site-packages/requests/sessions.py", line 484, in prepare_request
#     p.prepare(
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/site-packages/requests/models.py", line 371, in prepare
#     self.prepare_body(data, files, json)
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/site-packages/requests/models.py", line 513, in prepare_body
#     raise InvalidJSONError(ve, request=self)
# requests.exceptions.InvalidJSONError: Out of range float values are not JSON compliant
# Exception in thread Thread-3041:
# Traceback (most recent call last):
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/site-packages/requests/models.py", line 511, in prepare_body
#     body = complexjson.dumps(json, allow_nan=False)
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/json/__init__.py", line 234, in dumps
#     return cls(
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
# ValueError: Out of range float values are not JSON compliant
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/threading.py", line 1254, in run
#     self.function(*self.args, **self.kwargs)
#   File "/Users/Pat/Documents/GitHub/cosmicds/cosmicds/utils.py", line 295, in call_it
#     fun(*args, **kwargs)
#   File "/Users/Pat/Documents/GitHub/cosmicds/cosmicds/phases.py", line 68, in write_to_db
#     self.hub.broadcast(WriteToDatabaseMessage(self))
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/site-packages/glue/core/hub.py", line 215, in broadcast
#     handler(message)
#   File "/Users/Pat/Documents/GitHub/cosmicds/cosmicds/app.py", line 194, in _on_write_to_database
#     requests.put(self.story_state_endpoint, json=data)
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/site-packages/requests/api.py", line 130, in put
#     return request("put", url, data=data, **kwargs)
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/site-packages/requests/api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/site-packages/requests/sessions.py", line 573, in request
#     prep = self.prepare_request(req)
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/site-packages/requests/sessions.py", line 484, in prepare_request
#     p.prepare(
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/site-packages/requests/models.py", line 371, in prepare
#     self.prepare_body(data, files, json)
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/site-packages/requests/models.py", line 513, in prepare_body
#     raise InvalidJSONError(ve, request=self)
# requests.exceptions.InvalidJSONError: Out of range float values are not JSON compliant
# Exception in thread Thread-3128:
# Traceback (most recent call last):
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/site-packages/requests/models.py", line 511, in prepare_body
#     body = complexjson.dumps(json, allow_nan=False)
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/json/__init__.py", line 234, in dumps
#     return cls(
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
# ValueError: Out of range float values are not JSON compliant
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/threading.py", line 1254, in run
#     self.function(*self.args, **self.kwargs)
#   File "/Users/Pat/Documents/GitHub/cosmicds/cosmicds/utils.py", line 295, in call_it
#     fun(*args, **kwargs)
#   File "/Users/Pat/Documents/GitHub/cosmicds/cosmicds/phases.py", line 68, in write_to_db
#     self.hub.broadcast(WriteToDatabaseMessage(self))
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/site-packages/glue/core/hub.py", line 215, in broadcast
#     handler(message)
#   File "/Users/Pat/Documents/GitHub/cosmicds/cosmicds/app.py", line 194, in _on_write_to_database
#     requests.put(self.story_state_endpoint, json=data)
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/site-packages/requests/api.py", line 130, in put
#     return request("put", url, data=data, **kwargs)
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/site-packages/requests/api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/site-packages/requests/sessions.py", line 573, in request
#     prep = self.prepare_request(req)
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/site-packages/requests/sessions.py", line 484, in prepare_request
#     p.prepare(
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/site-packages/requests/models.py", line 371, in prepare
#     self.prepare_body(data, files, json)
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/site-packages/requests/models.py", line 513, in prepare_body
#     raise InvalidJSONError(ve, request=self)
# requests.exceptions.InvalidJSONError: Out of range float values are not JSON compliant
# Exception in thread Thread-5297:
# Traceback (most recent call last):
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/site-packages/requests/models.py", line 511, in prepare_body
#     body = complexjson.dumps(json, allow_nan=False)
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/json/__init__.py", line 234, in dumps
#     return cls(
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
# ValueError: Out of range float values are not JSON compliant
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/threading.py", line 1254, in run
#     self.function(*self.args, **self.kwargs)
#   File "/Users/Pat/Documents/GitHub/cosmicds/cosmicds/utils.py", line 295, in call_it
#     fun(*args, **kwargs)
#   File "/Users/Pat/Documents/GitHub/cosmicds/cosmicds/phases.py", line 68, in write_to_db
#     self.hub.broadcast(WriteToDatabaseMessage(self))
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/site-packages/glue/core/hub.py", line 215, in broadcast
#     handler(message)
#   File "/Users/Pat/Documents/GitHub/cosmicds/cosmicds/app.py", line 194, in _on_write_to_database
#     requests.put(self.story_state_endpoint, json=data)
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/site-packages/requests/api.py", line 130, in put
#     return request("put", url, data=data, **kwargs)
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/site-packages/requests/api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/site-packages/requests/sessions.py", line 573, in request
#     prep = self.prepare_request(req)
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/site-packages/requests/sessions.py", line 484, in prepare_request
#     p.prepare(
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/site-packages/requests/models.py", line 371, in prepare
#     self.prepare_body(data, files, json)
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/site-packages/requests/models.py", line 513, in prepare_body
#     raise InvalidJSONError(ve, request=self)
# requests.exceptions.InvalidJSONError: Out of range float values are not JSON compliant
# Exception in thread Thread-5319:
# Traceback (most recent call last):
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/site-packages/requests/models.py", line 511, in prepare_body
#     body = complexjson.dumps(json, allow_nan=False)
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/json/__init__.py", line 234, in dumps
#     return cls(
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
# ValueError: Out of range float values are not JSON compliant
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/threading.py", line 1254, in run
#     self.function(*self.args, **self.kwargs)
#   File "/Users/Pat/Documents/GitHub/cosmicds/cosmicds/utils.py", line 295, in call_it
#     fun(*args, **kwargs)
#   File "/Users/Pat/Documents/GitHub/cosmicds/cosmicds/phases.py", line 68, in write_to_db
#     self.hub.broadcast(WriteToDatabaseMessage(self))
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/site-packages/glue/core/hub.py", line 215, in broadcast
#     handler(message)
#   File "/Users/Pat/Documents/GitHub/cosmicds/cosmicds/app.py", line 194, in _on_write_to_database
#     requests.put(self.story_state_endpoint, json=data)
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/site-packages/requests/api.py", line 130, in put
#     return request("put", url, data=data, **kwargs)
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/site-packages/requests/api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/site-packages/requests/sessions.py", line 573, in request
#     prep = self.prepare_request(req)
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/site-packages/requests/sessions.py", line 484, in prepare_request
#     p.prepare(
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/site-packages/requests/models.py", line 371, in prepare
#     self.prepare_body(data, files, json)
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/site-packages/requests/models.py", line 513, in prepare_body
#     raise InvalidJSONError(ve, request=self)
# requests.exceptions.InvalidJSONError: Out of range float values are not JSON compliant
# Exception in thread Thread-5486:
# Traceback (most recent call last):
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/site-packages/requests/models.py", line 511, in prepare_body
#     body = complexjson.dumps(json, allow_nan=False)
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/json/__init__.py", line 234, in dumps
#     return cls(
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
# ValueError: Out of range float values are not JSON compliant
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/threading.py", line 1254, in run
#     self.function(*self.args, **self.kwargs)
#   File "/Users/Pat/Documents/GitHub/cosmicds/cosmicds/utils.py", line 295, in call_it
#     fun(*args, **kwargs)
#   File "/Users/Pat/Documents/GitHub/cosmicds/cosmicds/phases.py", line 68, in write_to_db
#     self.hub.broadcast(WriteToDatabaseMessage(self))
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/site-packages/glue/core/hub.py", line 215, in broadcast
#     handler(message)
#   File "/Users/Pat/Documents/GitHub/cosmicds/cosmicds/app.py", line 194, in _on_write_to_database
#     requests.put(self.story_state_endpoint, json=data)
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/site-packages/requests/api.py", line 130, in put
#     return request("put", url, data=data, **kwargs)
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/site-packages/requests/api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/site-packages/requests/sessions.py", line 573, in request
#     prep = self.prepare_request(req)
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/site-packages/requests/sessions.py", line 484, in prepare_request
#     p.prepare(
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/site-packages/requests/models.py", line 371, in prepare
#     self.prepare_body(data, files, json)
#   File "/Users/Pat/opt/anaconda3/envs/newbase/lib/python3.8/site-packages/requests/models.py", line 513, in prepare_body
#     raise InvalidJSONError(ve, request=self)
# requests.exceptions.InvalidJSONError: Out of range float values are not JSON compliant

# %%
# Run this to close the side menu
# app.drawer= False

# %%
# app.app_state.dark_mode = False

# %%
# it is usually best to always explicitly include the stage in the call. multiple stages may have the same variable name and so could have unintended side effects
# if the stage index is not included, it automatically assumes the current stage

def get_state(stage_index = None):
    """ Get the state for a particular stage or current stage"""
    
    if stage_index is None:
        stage_index = app.story_state.stage_index
    
    return app.story_state.stages[stage_index]['state'], stage_index


def go_to_marker(marker, stage_index = None):
    """ go to a marker"""
    state, stage_index = get_state(stage_index)
    
    if app.story_state.stage_index != stage_index:
        app.story_state.stage_index = stage_index
        
    state.marker = marker
    
    
def set_state_var(var, value, stage_index = None):
    """ set a state variable (maybe)"""
    
    state, stage_index = get_state(stage_index)
    
    if hasattr(state,var):
        setattr(state, var, value)
    else:
        print(f'Stage {stage_index} has not varialbe {var}')

def get_state_var(var, stage_index = None):
    """get the value of a state variable"""
    
    state, stage_index = get_state(stage_index)
    
    if hasattr(state,var):
        print(f'{var}:',getattr(state, var))
        return getattr(state, var)
    else:
        print(f"Variable {var} does not exist on Stage {stage_index}\n")
        print('\t Available variables are: \n',state)
        return state
        
def next_marker():
    
    state, stage_index = get_state(stage_index)
    
    stage_markers = app.story_state.stages[stage_index]['state'].markers
    
    marker = app.story_state.stages[stage_index]['state'].marker
    
    print(f'old marker {marker}')
    state.marker = stage_markers[stage_markers.index(marker)+1]
    print(f'new marker {state.marker}')

# %%
# go_to_marker("age_dis1", stage_index=5)
go_to_marker("new1", stage_index=5)

# %%
s = get_state_var('stu_high_age', stage_index =5) # get state variable from stage 5 #
set_state_var('stu_high_age', value = 6, stage_index = 5) # get state variable from the current stage
# Out:
# stu_high_age: 20
